# %%
import yfinance as yf

# %%
dat = yf.Tickers("COFF.L SBUX SJM BROS")
data = dat.history(period="1y")
data.head()
# Out:
# [*********************100%***********************]  4 of 4 completed
# Price           Close                                   Dividends              \
# Ticker           BROS     COFF.L       SBUX         SJM      BROS COFF.L SBUX
# Date
# 2025-03-18  63.009998  67.415001  95.641068  106.572311       0.0    0.0  0.0
# 2025-03-19  66.290001  68.370003  96.526634  105.889847       0.0    0.0  0.0
# 2025-03-20  65.489998  68.864998  96.614212  105.111229       0.0    0.0  0.0
# 2025-03-21  65.430000  68.349998  94.463547  105.447662       0.0    0.0  0.0
# 2025-03-24  70.449997  68.894997  93.149796  107.418198       0.0    0.0  0.0
#
# Price                 High             ...       Open              \
# Ticker      SJM       BROS     COFF.L  ...       SBUX         SJM
# Date                                   ...
# 2025-03-18  0.0  63.369999  68.459999  ...  96.565563  107.437419
# 2025-03-19  0.0  67.198997  69.129997  ...  95.631332  105.687981
# 2025-03-20  0.0  67.488998  69.699997  ...  96.195758  105.966729
# 2025-03-21  0.0  65.699997  69.360001  ...  95.310189  104.947822
# 2025-03-24  0.0  71.250000  70.559998  ...  95.397767  105.755255
#
# Price      Stock Splits                      Volume                      \
# Ticker             BROS COFF.L SBUX  SJM       BROS  COFF.L        SBUX
# Date
# 2025-03-18          0.0    0.0  0.0  0.0  2499000.0  2167.0   7423400.0
# 2025-03-19          0.0    0.0  0.0  0.0  5356200.0  4887.0   4982700.0
# 2025-03-20          0.0    0.0  0.0  0.0  4395400.0   458.0   5952800.0
# 2025-03-21          0.0    0.0  0.0  0.0  2807100.0  1021.0  11366000.0
# 2025-03-24          0.0    0.0  0.0  0.0  4607500.0  2286.0   8265000.0
#
# Price
# Ticker            SJM
# Date
# 2025-03-18  1249600.0
# 2025-03-19  1292600.0
# 2025-03-20  1185300.0
# 2025-03-21  2326900.0
# 2025-03-24  1427200.0
#
# [5 rows x 28 columns]

# %%
# Flatten the column MultiIndex to single header
data.columns = ["_".join(filter(None, col)).strip() for col in data.columns.values]

# %%
data.to_csv("../../data/landing/relevant_stocks.csv")
